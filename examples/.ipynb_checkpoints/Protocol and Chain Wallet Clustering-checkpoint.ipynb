# %% [markdown]
# ## Differentiating users based on their onchain interactions
#
# We will take all wallets who have interacted with a given contract address, and see if we can add "features" to spot different clusters of wallets. A feature is just some characteristic/variable, such as if a wallet has an ENS domain registered or not.
#
# This can be done in four steps:
# 1. Write a query on Dune where the returned data has columns for each feature and rows for each wallet
# 2. Add parameters for "contract_address", "blockchain", "month", and "minimum calls"
# 3. Use the dune-client to pull the data for Opensea in September 2023 versus September 2022
# 4. Use scikit-learn and pandas to cluster the data (PCA + k-means)
#
# I've already [written the query here](https://dune.com/queries/3070841):

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This query uses the following data sources:
# - ENS spell
# - dex.trades and nft.trades
# - CEX address labels
# - Raw transactions

# %% [markdown]
# ## Pulling the data from the API
#
# Let's run the query for Opensea seaport, grabbing wallets that called Seaport on Ethereum at least five transactions during the month of September 2021 - the height of the bull market.

# %%
import warnings
warnings.filterwarnings("ignore")

from dune_client.types import QueryParameter
from dune_client.client import DuneClient
from dune_client.query import QueryBase

from dotenv import load_dotenv
import pandas as pd
import numpy as np

#you should use a .env file for your api key
load_dotenv()
dune = DuneClient.from_env()

#putting in our parameters
query = QueryBase(
    query_id=3070841,
    params=[
        QueryParameter.text_type(name="blockchain", value="ethereum"),
        QueryParameter.number_type(name="minimum calls", value=5),
        QueryParameter.date_type(name="month", value="2021-09-01 00:00:00"),
    ],
)

dune = DuneClient.from_env()
results = dune.run_query(query) #does a fresh run of the query, default is on medium engine.

# results = dune.get_latest_result(3070841, max_age_hours=8) #use this to get results from the last run, instead of re-running it
query_result = pd.DataFrame(results.result.rows)
query_result.head(1)
# Out:
# 2023-10-03 23:03:31,879 INFO dune_client.api.base executing 3070841 on medium cluster
# 2023-10-03 23:03:32,517 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:33,877 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:35,246 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:36,580 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:37,932 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:39,298 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:40,689 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:42,008 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:43,331 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:44,676 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:46,067 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:47,415 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:48,758 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:50,080 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:51,418 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:52,776 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:54,088 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:55,438 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:56,816 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:58,149 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:03:59,511 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:00,887 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:02,239 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:03,584 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:04,956 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:06,294 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:07,883 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:09,777 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:11,101 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:12,492 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:13,821 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:15,298 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:16,673 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:18,214 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:19,545 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:20,880 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:22,216 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:23,592 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:24,922 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:26,257 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:27,591 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:28,957 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:30,285 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:31,636 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:32,947 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:34,306 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# 2023-10-03 23:04:35,626 INFO dune_client.api.base waiting for query execution 01HBWA81RPW662HK19HZF0SGAC to complete: ExecutionState.EXECUTING
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# You can see the features (columns) we're working with below. Hopefully the column names are self explanatory!

# %%
query_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %% [markdown]
# It costs 10 credits to run on the medium engine in 1 minute, and costs 200 credits (1 credit per 1000 datapoints) for the 15x13250 datapoints I will be exporting. You're given 2500 free tier credits.
#
# You can also run it with free tier in app, and then use the get latest results endpoint (which is what I did above).

# %% [markdown]
# ## Cleaning the Data
#
# Let's get a quick summary of the data to see if we need to remove outliers or apply any transforms.

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.grid(False)
query_result.hist(bins=25, ax=ax)
plt.show()

# %% [markdown]
# There are clearly some wild outliers in many of these features, so we will need to take the log transform of some of these values

# %%
query_result_tf = query_result

log_transform_columns = ['dex_trades', 'dex_volume_usd', 'funding_sources',
       'gas_used', 'nft_trades', 'nft_volume_usd', 'times_called',
       'times_cex_funded', 'times_funded', 'txs']

query_result_tf[log_transform_columns] = query_result_tf[log_transform_columns].applymap(lambda x: np.log1p(x + 1))

#let's plot again
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.grid(False)
query_result.hist(bins=25, ax=ax)
plt.show()

# %% [markdown]
# There we go! Now this looks log normal, so we can move on.

# %% [markdown]
# ## Clustering the wallets
#
# Let's do PCA and Clustering (elbow and stuff)

# %%
from sklearn.decomposition import PCA

numerics = ['int64','float64']
df_filtered = query_result_tf.select_dtypes(include=numerics)

print(df_filtered.columns)

pca = PCA()
df_pca = pca.fit_transform(X=df_filtered)
df_pca = pd.DataFrame(df_pca)
df_pca.head()
# Out:
# Index(['blockchains_used', 'dex_trades', 'dex_volume_usd', 'funding_sources',
#        'gas_used', 'has_ens', 'nft_trades', 'nft_volume_usd', 'times_called',
#        'times_cex_funded', 'times_funded', 'txs', 'wallet_days_age'],
#       dtype='object')
#            0         1          2         3         4         5         6   \
# 0  147.780510  0.012955  13.724563  8.481728  0.727374  0.908085 -1.946216
# 1 -188.220436 -1.714578  14.083721  5.545983  2.754211  1.645137 -2.210343
# 2  420.799527 -4.384238  -1.470852 -3.659920  1.260553  3.147789 -0.895689
# 3 -383.262825  0.693517   9.068792  1.053149 -1.323589  2.834560 -1.695157
# 4 -223.255537  0.935116   9.998052  2.700132 -0.759457  2.953865 -2.213993
#
#          7         8         9         10        11        12
# 0 -2.281498  1.340227  4.117827 -0.448641 -0.369135 -0.039305
# 1 -1.613098  1.445130  3.996202 -0.217190 -0.122902  0.107602
# 2 -1.450241 -1.095471  3.007036 -0.061416  0.105461  0.506307
# 3 -0.029044  0.542962  2.359053  1.099935  0.425080  0.223947
# 4 -1.009301  0.870010  2.108693 -0.043890  0.862811 -0.245167

# %%
import seaborn as sns

sns.jointplot(x=df_pca[0], y=df_pca[1], kind="hex", color="#4CB391")

# %% [markdown]
# We can kind of see a few clusters appearing, but let's use k-means to delineate them better.

# %%
import numpy as np
import os
import pdb

# to make this notebook's output stable across runs
np.random.seed(42)

'''unsupervised classifiers'''
from sklearn.cluster import KMeans
k = 3
kmeans = KMeans(n_clusters=k)
y_pred = kmeans.fit_predict(df_pca)
plt.figure(figsize=(9, 3.5))
plt.plot(df_pca.loc[y_pred==0, 0], df_pca.loc[y_pred==0, 1], "yo", label="Cluster 1")
plt.plot(df_pca.loc[y_pred==1, 0], df_pca.loc[y_pred==1, 1], "bs", label="Cluster 2")
plt.plot(df_pca.loc[y_pred==2, 0], df_pca.loc[y_pred==2, 1], "g^", label="Cluster 3")
plt.xlabel("PCA 0", fontsize=14)
plt.ylabel("PCA 1", fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()

# %%
df_filtered["clusters"] = y_pred

fig, ax = plt.subplots(4, 4, figsize=(10, 10))

x=0
y=0
for idx, column in enumerate(df_filtered.columns[:-1]):
    # print(idx, column)
    # print(x,y)
    sns.histplot(
        df_filtered, x=column, hue="clusters", element="step",
        stat="density", common_norm=False, ax = ax[x,y]
    )
    # ax[x,y].set_title(column,fontweight="bold", size=10)
    ax[x,y].set_ylabel('')
    if y == 3:
        y = 0
        x+=1
    else:
        y+=1
        
plt.tight_layout()
plt.show()

# %% [markdown]
# From this, I can see that `wallet_days_age` and `times_cex_funded` have the cleanest variance between clusters.

# %% [markdown]
# ## What comes next?
#
# Go add fork the query and add more features, change the contracts, change the number of clusters, etc.
#
# Have fun, and please reach out if you have any questions :)
