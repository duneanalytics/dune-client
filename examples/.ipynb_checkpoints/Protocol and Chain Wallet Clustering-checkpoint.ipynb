# %% [markdown]
# ## Differentiating users based on their onchain interactions
#
# We will take all wallets who have interacted with a given contract address, and see if we can add "features" to spot different clusters of wallets. A feature is just some characteristic/variable, such as if a wallet has an ENS domain registered or not.
#
# This can be done in four steps:
# 1. Write a query on Dune where the returned data has columns for each feature and rows for each wallet
# 2. Add parameters for "contract_address", "blockchain", "month", and "minimum calls"
# 3. Use the dune-client to pull the data for Opensea in September 2023 versus September 2022
# 4. Use scikit-learn and pandas to cluster the data (PCA + k-means)
#
# I've already [written the query here](https://dune.com/queries/3070841):

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This query uses the following data sources:
# - ENS spell
# - dex.trades and nft.trades
# - CEX address labels
# - Raw transactions

# %% [markdown]
# ## Pulling the data from the API
#
# Let's run the query for Opensea seaport, grabbing wallets that called Seaport on Ethereum at least five transactions during the month of September 2023.

# %%
from dune_client.types import QueryParameter
from dune_client.client import DuneClient
from dune_client.query import QueryBase

from dotenv import load_dotenv
import pandas as pd

#you should use a .env file for your api key
load_dotenv()
dune = DuneClient.from_env()

#putting in our parameters
query = QueryBase(
    query_id=3070841,
    params=[
        QueryParameter.text_type(name="blockchain", value="ethereum"),
        QueryParameter.number_type(name="minimum calls", value=5),
        QueryParameter.date_type(name="month", value="2023-09-01 00:00:00"),
    ],
)

dune = DuneClient.from_env()
# results = dune.run_query(query) #does a fresh run of the query, default is on medium engine.

results = dune.get_latest_result(3070841, max_age_hours=8) #use this to get results from the last run, instead of re-running it
query_result = pd.DataFrame(results.result.rows)
query_result.head(1)
# Out:
#    blockchains_used  dex_trades  dex_volume_usd  funding_sources     gas_used  \
# 0                 6           0             0.0               27  21982817696
#
#    has_ens  nft_trades  nft_volume_usd  times_called  times_cex_funded  \
# 0        0       88224    2.866869e+07          2681               820
#
#    times_funded    txs                                      wallet  \
# 0           836  97762  0xf408bee3443d0397e2c1cde588fb060ac657006f
#
#                    wallet_date  wallet_days_age
# 0  2021-10-25 22:30:21.000 UTC              707

# %% [markdown]
# You can see the features (columns) we're working with below. Hopefully the column names are self explanatory!

# %%
query_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13250 entries, 0 to 13249
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   blockchains_used  13250 non-null  int64
#  1   dex_trades        13250 non-null  int64
#  2   dex_volume_usd    13250 non-null  float64
#  3   funding_sources   13250 non-null  int64
#  4   gas_used          13250 non-null  int64
#  5   has_ens           13250 non-null  int64
#  6   nft_trades        13250 non-null  int64
#  7   nft_volume_usd    13250 non-null  float64
#  8   times_called      13250 non-null  int64
#  9   times_cex_funded  13250 non-null  int64
#  10  times_funded      13250 non-null  int64
#  11  txs               13250 non-null  int64
#  12  wallet            13250 non-null  object
#  13  wallet_date       13250 non-null  object
#  14  wallet_days_age   13250 non-null  int64
# dtypes: float64(2), int64(11), object(2)
# memory usage: 1.5+ MB

# %% [markdown]
# It costs 10 credits to run on the medium engine in 1 minute, and costs 200 credits (1 credit per 1000 datapoints) for the 15x13250 datapoints I will be exporting. You're given 2500 free tier credits.
#
# You can also run it with free tier in app, and then use the get latest results endpoint (which is what I did above).

# %% [markdown]
# ## Cleaning the Data
#
# Let's get a quick summary of the data to see if we need to remove outliers or apply any transforms.

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fig, ax = plt.subplots(1, 1, figsize=(12, 12))
ax.grid(False)
query_result.hist(bins=25, ax=ax)
plt.show()
# Out:
# C:\Users\13104\AppData\Local\Temp\ipykernel_23132\653767530.py:6: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   query_result.hist(bins=25, ax=ax)

# %% [markdown]
# There are clearly some wild outliers in many of these features, so we will need to take the log transform of some of these values.

# %% [markdown]
# ## Clustering the wallets
#
# Let's do PCA and Clustering (elbow and stuff)

# %%
from sklearn.decomposition import PCA

numerics = ['int64','float64']
df_filtered = query_result.select_dtypes(include=numerics)

pca = PCA()
df_pca = pca.fit_transform(X=df_filtered)
df_pca = pd.DataFrame(df_pca)
df_pca.head()
# Out:
#              0             1             2             3             4   \
# 0  2.173234e+10 -5.259188e+07  3.008978e+07  50397.230658  61374.921164
# 1  1.295803e+10 -3.143747e+07  1.912234e+07  32104.949897  40924.706455
# 2  1.892037e+08  4.732278e+06 -7.857890e+05   -603.587399    569.878607
# 3  1.376406e+08 -6.788194e+05  1.881337e+06    474.293665    335.074681
# 4  8.755993e+08 -2.515907e+06  2.336216e+06   4072.609435   4655.726154
#
#             5            6            7           8           9            10  \
# 0  1707.876562  1933.646891 -1756.700783  659.279979  361.245823  1457.149657
# 1  1627.596334  1513.299242 -1207.090700  498.867482  419.180488  1822.306639
# 2   109.400129  -415.822973   -94.008166   46.477351   95.161014   492.754916
# 3   -74.159744   419.144500   -67.456158   34.015968   58.033622   278.037868
# 4   205.921780   376.981260  -228.812590   -2.870984   43.379858   195.152325
#
#          11        12
# 0 -1.296572  1.084737
# 1 -0.923975  0.029113
# 2  1.136896  0.147824
# 3  0.326692 -1.000700
# 4 -0.223763  0.181792

# %%
import seaborn as sns

sns.jointplot(x=df_pca[0], y=df_pca[1], kind="hex", color="#4CB391")

# %%
import numpy as np
import os
import pdb
import warnings
warnings.filterwarnings("ignore")

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

from sklearn.datasets import load_iris
data = load_iris()
X = data.data
y = data.target
plt.figure(figsize=(9, 3.5))

plt.plot(X[0, 2], X[0, 3], "yo", label="Iris setosa")
plt.plot(X[y==1, 2], X[y==1, 3], "bs", label="Iris versicolor")
plt.plot(X[y==2, 2], X[y==2, 3], "g^", label="Iris virginica")
plt.xlabel("Petal length", fontsize=14)
plt.ylabel("Petal width", fontsize=14)
plt.legend(fontsize=12)

'''unsupervised classifiers'''
from sklearn.cluster import KMeans
k = 3
kmeans = KMeans(n_clusters=k)
y_pred = kmeans.fit_predict(X)
plt.figure(figsize=(9, 3.5))
plt.plot(X[y_pred==0, 2], X[y_pred==0, 3], "yo", label="Cluster 1")
plt.plot(X[y_pred==1, 2], X[y_pred==1, 3], "bs", label="Cluster 2")
plt.plot(X[y_pred==2, 2], X[y_pred==2, 3], "g^", label="Cluster 3")
plt.xlabel("Petal length", fontsize=14)
plt.ylabel("Petal width", fontsize=14)
plt.legend(loc="upper left", fontsize=12)
plt.show()

kmeans.inertia_ #use .score(X) for the negative, since negative is better
kmeans.inertia_

#higher k means lower inertia, just because more clusters means lower distance in general. Can use elbow rule instead: 
kmeans_per_k = [KMeans(n_clusters=k, random_state=42).fit(X)
                for k in range(1, 10)]

inertias = [model.inertia_ for model in kmeans_per_k]
plt.figure(figsize=(8, 3.5))
plt.plot(range(1, 10), inertias, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)
plt.annotate('Elbow',
             xy=(2, inertias[1]),
             xytext=(0.35, 0.55),
             textcoords='figure fraction',
             fontsize=16,
             arrowprops=dict(facecolor='black', shrink=0.1)
            )
plt.axis([1, 8.5, 0, 1300])
plt.show()

# %% [markdown]
# ## What comes next?
#
# Go add fork the query and add more features, change the contracts, change the number of clusters, etc.
#
# Have fun, and please reach out if you have any questions :)
